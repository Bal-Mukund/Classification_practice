# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_train = np.array([0., 1, 2, 3, 4, 5])
y_train = np.array([0,  0, 0, 1, 1, 1])
X_train2 = np.array([[0.5, 1.5], [1,1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])
y_train2 = np.array([0, 0, 0, 1, 1, 1])

# %%
pos = y_train == 1
neg = y_train == 0

# %%
X_train2.shape
# Out:
# (6, 2)

# %%
plt.scatter(x_train[neg], y_train[neg], marker="o", s=200, color= "white", edgecolors="green", lw=3, label="y=0")
plt.scatter(x_train[pos], y_train[pos], marker="x", s=200, color="red", lw=3, label="X=1" )
plt.legend()
plt.show()
